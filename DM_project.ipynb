# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\PHP\diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
 df["SkinThickness"]=df["SkinThickness"].replace(0,df["SkinThickness"].mean())

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72      35.000000        0  33.6
# 1              1       85             66      29.000000        0  26.6
# 2              8      183             64      20.536458        0  23.3
# 3              1       89             66      23.000000       94  28.1
# 4              0      137             40      35.000000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76      48.000000      180  32.9
# 764            2      122             70      27.000000        0  36.8
# 765            5      121             72      23.000000      112  26.2
# 766            1      126             60      20.536458        0  30.1
# 767            1       93             70      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["Insulin"]= df["Insulin"].replace(0,df["Insulin"].mean())

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000   79.799479  33.6
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
plt.figure(figsize =(12,7))
plt.scatter("Pregnancies","Insulin",data=df)
plt.title("Pregnancy Vs Insulin")
plt.xlabel("pregnancy")
plt.ylabel("Insulin")
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.scatter("BloodPressure","Insulin",data=df)
plt.title("Blood_Pressure Vs Insulin")
plt.xlabel("Blood_Pressure")
plt.ylabel("Insulin")
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.scatter("Glucose","BMI",data=df)
plt.title("Glucose Vs BMI")
plt.xlabel("Glucose")
plt.ylabel("Bmi")
plt.show()

# %%
def remove(dataF):
    for itr in fataF.columns:
        q1=df[itr].quantile(0.25)
        q2=df[itr].quantile(0.75)
        iqr=q2-q1
        lower_l=q1-1.5*iqr
        upper_l=q2+1.5*iqr
        dataF=dataF[dataF[itr]>lower_l | dataF[itr]<upper_l]
    return dataF

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(["Outcome"], axis=1)
y=df["Outcome"]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72      35.000000   79.799479  33.6
# 1              1       85             66      29.000000   79.799479  26.6
# 2              8      183             64      20.536458   79.799479  23.3
# 3              1       89             66      23.000000   94.000000  28.1
# 4              0      137             40      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10      101             76      48.000000  180.000000  32.9
# 764            2      122             70      27.000000   79.799479  36.8
# 765            5      121             72      23.000000  112.000000  26.2
# 766            1      126             60      20.536458   79.799479  30.1
# 767            1       93             70      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=42)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 60             2       84              0      20.536458   79.799479   0.0
# 618            9      112             82      24.000000   79.799479  28.2
# 346            1      139             46      19.000000   83.000000  28.7
# 294            0      161             50      20.536458   79.799479  21.9
# 231            6      134             80      37.000000  370.000000  46.2
# ..           ...      ...            ...            ...         ...   ...
# 71             5      139             64      35.000000  140.000000  28.6
# 106            1       96            122      20.536458   79.799479  22.4
# 270           10      101             86      37.000000   79.799479  45.6
# 435            0      141              0      20.536458   79.799479  42.4
# 102            0      125             96      20.536458   79.799479  22.5
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# ...

# %%
y_train
# Out:
# 60     0
# 618    1
# 346    0
# 294    0
# 231    1
#       ..
# 71     0
# 106    0
# 270    1
# 435    1
# 102    0
# Name: Outcome, Length: 614, dtype: int64

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 668            6       98             58      33.000000  190.000000  34.0
# 324            2      112             75      32.000000   79.799479  35.7
# 624            2      108             64      20.536458   79.799479  30.8
# 690            8      107             80      20.536458   79.799479  24.6
# 473            7      136             90      20.536458   79.799479  29.9
# ..           ...      ...            ...            ...         ...   ...
# 355            9      165             88      20.536458   79.799479  30.4
# 534            1       77             56      30.000000   56.000000  33.3
# 344            8       95             72      20.536458   79.799479  36.8
# 296            2      146             70      38.000000  360.000000  28.0
# 462            8       74             70      40.000000   49.000000  35.3
#
#      DiabetesPedigreeFunction  Age
# 668                     0.430   43
# ...

# %%
y_test
# Out:
# 668    0
# 324    0
# 624    0
# 690    0
# 473    0
#       ..
# 355    1
# 534    0
# 344    0
# 296    1
# 462    0
# Name: Outcome, Length: 154, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()

# %%
logreg.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x_test,y_test)
# Out:
# 0.7532467532467533

# %%
preg=int(input("Give the number of pregnancies you had in Past:"))
gluc=float(input("Give your measured glucose level:"))
bp=float(input("Give your measured Bloob Pressure:"))
sk=float(input("Give your measured skin thickness:"))
ins=float(input("Give your measured insulin level:"))
bmi=float(input("Give your BMI Index:"))
dbf=float(input("Give your Diabetes degree function:"))
age=int(input("Give your age:"))
val=logreg.predict(([[preg,gluc,bp,sk,ins,bmi,dbf,age]]))
if(val>0.5):
    print("person is diabetic")
else:
    print("Person is Not diabetic and healthy")
# Out:
# Give the number of pregnancies you had in Past:6
# Give your measured glucose level:183.6
# Give your measured Bloob Pressure:79.999
# Give your measured skin thickness:21
# Give your measured insulin level:99
# Give your BMI Index:30
# Give your Diabetes degree function:2.456
# Give your age:35
# person is diabetic
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
